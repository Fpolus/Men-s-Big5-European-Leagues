# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np
from splinter import Browser
import time

# %%
teams_df = pd.read_csv('../Resources/all_premier_league_teams.csv')
teams_df.head()

# Extracting the ID from the 'link' column in the DataFrame
teams_df['link'] = teams_df['link'].apply(lambda x: x.split('/')[-3])

# Display the updated DataFrame
print(teams_df)
# Out:
#                team      link
# 0   Manchester City  b8fd03ef
# 1    Manchester Utd  19538871
# 2         Tottenham  361ca564
# 3         Liverpool  822bd0ba
# 4           Chelsea  cff3d9bb
# 5           Arsenal  18bb7c10
# 6           Burnley  943e8050
# 7           Everton  d3fd31cc
# 8    Leicester City  a2d435b3
# 9     Newcastle Utd  b2b47a98
# 10   Crystal Palace  47c64c55
# 11      Bournemouth  4ba7cbea
# 12         West Ham  7c21e445
# 13          Watford  2abfe087
# 14         Brighton  d07537b9
# 15     Huddersfield  f5922ca5
# 16      Southampton  33c895d4
# 17     Swansea City  fb10988f
# 18       Stoke City  17892952
# 19        West Brom  60c6b05f
# 20           Wolves  8cec06e1
# 21     Cardiff City  75fae011
# 22           Fulham  fd962109
# 23    Sheffield Utd  1df6b87e
# 24      Aston Villa  8602292d
# 25     Norwich City  1c781004
# 26     Leeds United  5bfb9659
# 27        Brentford  cd051869
# 28  Nott'ham Forest  e4a775cb
# 29       Luton Town  e297cd13

# %%
# Prompt user for the common year range
year_i = input('Enter the starting year (YYYY format): ')
year_f = input('Enter the ending year (type in same year for single year analysis): ')

# Convert user inputs to integers
year_i = int(year_i)
year_f = int(year_f)

# Create a Chrome browser instance
browser = Browser('chrome')

# Iterate through each team in the DataFrame using the common year range
for index, row in teams_df.iterrows():
    team = row['team']
    link = row['link']

    base_url = 'https://fbref.com'
    team_url = team.replace(' ', '-')

    # Generate the range of years based on the common year range
    years = range(year_i, year_f + 1)

    combined_data = []

    # Visit each year's URL for the team
    for year in years:
        url = f'{base_url}/en/squads/{link}/{year}-{year + 1}/{team_url}-Stats'
        
        # Print the generated URLs for each team
        print(f'Team: {team}, URLs: {url}')
        
        # Visit the page and create the soup object
        browser.visit(url)
        time.sleep(5)
        browser.is_element_present_by_id('stats_shooting_9', wait_time=5)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        
        # Scrape the offensive table from the page
        try:
            table = soup.find('table', {'class': 'stats_table sortable min_width now_sortable sticky_table eq1 re1 le1', 
                                        'id': 'stats_shooting_9'})

            # Execute JavaScript to stop further page loading
            browser.execute_script("window.stop();")

            # Extract data from the table
            data_list = []

            # Iterate through the rows in the table body
            for row in table.find('tbody').find_all('tr'):
                # Extract the 'Date' from the <th> with scope 'row' and class 'left'
                player_elem = row.find('th', {'scope': 'row', 'class': 'left'})
                player = player_elem.get_text() if player_elem else None

                # Other columns extracted from <td> elements
                columns = [cell.get_text() for cell in row.find_all('td')]

                # Insert 'date' into the beginning of the columns list if it exists
                if player_elem:
                    columns.insert(0, player)

                # Append the row data to the list
                data_list.append(columns)

            # Append the scraped data to combined_data
            combined_data.extend(data_list)
            
        except AttributeError:
            # If 'stats_standard_9' ID isn't found, print a message and continue
            print(f"No 'stats_shooting_9' table found for {team} in the specified year range.")
            continue

    # Define columns including 'Notes'
    columns = ['Player', 'Nation', 'Pos', 'Age', '90s', 'Gls', 'Sh', 'SoT', 'Sot%', 'sh/90', 'SoT/90',
              'G/Sh', 'G/SoT', 'Dist', 'FK', 'PK', 'PKat', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG','Matches'
]

    # Create a Pandas DataFrame
    team_df = pd.DataFrame(combined_data, columns=columns)

    # Save the data for each team to a separate CSV file
    # Assuming 'team_df' contains the scraped and processed data for each team
    team_df.to_csv(f'../Resources/Shooting_Stats/{team}_shooting_stats.csv', index=False)
# Out:
# Enter the starting year (YYYY format): 2017
# Enter the ending year (type in same year for single year analysis): 2023
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2017-2018/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2018-2019/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2019-2020/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2020-2021/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2021-2022/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2022-2023/Manchester-City-Stats
# Team: Manchester City, URLs: https://fbref.com/en/squads/b8fd03ef/2023-2024/Manchester-City-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2017-2018/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2018-2019/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2019-2020/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2020-2021/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2021-2022/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2022-2023/Manchester-Utd-Stats
# Team: Manchester Utd, URLs: https://fbref.com/en/squads/19538871/2023-2024/Manchester-Utd-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2017-2018/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2018-2019/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2019-2020/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2020-2021/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2021-2022/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2022-2023/Tottenham-Stats
# Team: Tottenham, URLs: https://fbref.com/en/squads/361ca564/2023-2024/Tottenham-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2017-2018/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2018-2019/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2019-2020/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2020-2021/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2021-2022/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2022-2023/Liverpool-Stats
# Team: Liverpool, URLs: https://fbref.com/en/squads/822bd0ba/2023-2024/Liverpool-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2017-2018/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2018-2019/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2019-2020/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2020-2021/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2021-2022/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2022-2023/Chelsea-Stats
# Team: Chelsea, URLs: https://fbref.com/en/squads/cff3d9bb/2023-2024/Chelsea-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2017-2018/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2018-2019/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2019-2020/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2020-2021/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2021-2022/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2022-2023/Arsenal-Stats
# Team: Arsenal, URLs: https://fbref.com/en/squads/18bb7c10/2023-2024/Arsenal-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2017-2018/Burnley-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2018-2019/Burnley-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2019-2020/Burnley-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2020-2021/Burnley-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2021-2022/Burnley-Stats
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2022-2023/Burnley-Stats
# No 'stats_shooting_9' table found for Burnley in the specified year range.
# Team: Burnley, URLs: https://fbref.com/en/squads/943e8050/2023-2024/Burnley-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2017-2018/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2018-2019/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2019-2020/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2020-2021/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2021-2022/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2022-2023/Everton-Stats
# Team: Everton, URLs: https://fbref.com/en/squads/d3fd31cc/2023-2024/Everton-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2017-2018/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2018-2019/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2019-2020/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2020-2021/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2021-2022/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2022-2023/Leicester-City-Stats
# Team: Leicester City, URLs: https://fbref.com/en/squads/a2d435b3/2023-2024/Leicester-City-Stats
# No 'stats_shooting_9' table found for Leicester City in the specified year range.
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2017-2018/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2018-2019/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2019-2020/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2020-2021/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2021-2022/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2022-2023/Newcastle-Utd-Stats
# Team: Newcastle Utd, URLs: https://fbref.com/en/squads/b2b47a98/2023-2024/Newcastle-Utd-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2017-2018/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2018-2019/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2019-2020/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2020-2021/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2021-2022/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2022-2023/Crystal-Palace-Stats
# Team: Crystal Palace, URLs: https://fbref.com/en/squads/47c64c55/2023-2024/Crystal-Palace-Stats
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2017-2018/Bournemouth-Stats
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2018-2019/Bournemouth-Stats
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2019-2020/Bournemouth-Stats
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2020-2021/Bournemouth-Stats
# No 'stats_shooting_9' table found for Bournemouth in the specified year range.
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2021-2022/Bournemouth-Stats
# No 'stats_shooting_9' table found for Bournemouth in the specified year range.
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2022-2023/Bournemouth-Stats
# Team: Bournemouth, URLs: https://fbref.com/en/squads/4ba7cbea/2023-2024/Bournemouth-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2017-2018/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2018-2019/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2019-2020/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2020-2021/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2021-2022/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2022-2023/West-Ham-Stats
# Team: West Ham, URLs: https://fbref.com/en/squads/7c21e445/2023-2024/West-Ham-Stats
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2017-2018/Watford-Stats
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2018-2019/Watford-Stats
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2019-2020/Watford-Stats
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2020-2021/Watford-Stats
# No 'stats_shooting_9' table found for Watford in the specified year range.
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2021-2022/Watford-Stats
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2022-2023/Watford-Stats
# No 'stats_shooting_9' table found for Watford in the specified year range.
# Team: Watford, URLs: https://fbref.com/en/squads/2abfe087/2023-2024/Watford-Stats
# No 'stats_shooting_9' table found for Watford in the specified year range.
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2017-2018/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2018-2019/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2019-2020/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2020-2021/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2021-2022/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2022-2023/Brighton-Stats
# Team: Brighton, URLs: https://fbref.com/en/squads/d07537b9/2023-2024/Brighton-Stats
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2017-2018/Huddersfield-Stats
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2018-2019/Huddersfield-Stats
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2019-2020/Huddersfield-Stats
# No 'stats_shooting_9' table found for Huddersfield in the specified year range.
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2020-2021/Huddersfield-Stats
# No 'stats_shooting_9' table found for Huddersfield in the specified year range.
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2021-2022/Huddersfield-Stats
# No 'stats_shooting_9' table found for Huddersfield in the specified year range.
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2022-2023/Huddersfield-Stats
# No 'stats_shooting_9' table found for Huddersfield in the specified year range.
# Team: Huddersfield, URLs: https://fbref.com/en/squads/f5922ca5/2023-2024/Huddersfield-Stats
# No 'stats_shooting_9' table found for Huddersfield in the specified year range.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 84
#      80 team_df = pd.DataFrame(combined_data, columns=columns)
#      82 # Save the data for each team to a separate CSV file
#      83 # Assuming 'team_df' contains the scraped and processed data for each team
# ---> 84 team_df.to_csv(f'../Shooting_Stats/{team}_shooting_stats.csv', index=False)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
#    3713     header=header,
#    (...)
#    3717     decimal=decimal,
#    3718 )
# -> 3720 return DataFrameRenderer(formatter).to_csv(
#    3721     path_or_buf,
#    3722     lineterminator=lineterminator,
#    3723     sep=sep,
#    3724     encoding=encoding,
#    3725     errors=errors,
#    3726     compression=compression,
#    3727     quoting=quoting,
#    3728     columns=columns,
#    3729     index_label=index_label,
#    3730     mode=mode,
#    3731     chunksize=chunksize,
#    3732     quotechar=quotechar,
#    3733     date_format=date_format,
#    3734     doublequote=doublequote,
#    3735     escapechar=escapechar,
#    3736     storage_options=storage_options,
#    3737 )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\formats\format.py:1189, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1168     created_buffer = False
#    1170 csv_formatter = CSVFormatter(
#    1171     path_or_buf=path_or_buf,
#    1172     lineterminator=lineterminator,
#    (...)
#    1187     formatter=self.fmt,
#    1188 )
# -> 1189 csv_formatter.save()
#    1191 if created_buffer:
#    1192     assert isinstance(path_or_buf, StringIO)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\formats\csvs.py:241, in CSVFormatter.save(self)
#     237 """
#     238 Create the writer & save.
#     239 """
#     240 # apply compression and byte/text conversion
# --> 241 with get_handle(
#     242     self.filepath_or_buffer,
#     243     self.mode,
#     244     encoding=self.encoding,
#     245     errors=self.errors,
#     246     compression=self.compression,
#     247     storage_options=self.storage_options,
#     248 ) as handles:
#     249
#     250     # Note: self.encoding is irrelevant here
#     251     self.writer = csvlib.writer(
#     252         handles.handle,
#     253         lineterminator=self.lineterminator,
#    (...)
#     258         quotechar=self.quotechar,
#     259     )
#     261     self._save()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\common.py:734, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     732 # Only for write methods
#     733 if "r" not in mode and is_path:
# --> 734     check_parent_directory(str(handle))
#     736 if compression:
#     737     if compression != "zstd":
#     738         # compression libraries do not like an explicit text-mode
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\io\common.py:597, in check_parent_directory(path)
#     595 parent = Path(path).parent
#     596 if not parent.is_dir():
# --> 597     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\Shooting_Stats'

# %%
# Quit the browser session
browser.quit()
